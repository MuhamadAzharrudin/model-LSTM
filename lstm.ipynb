# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from tensorflow.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, TimeDistributed, RepeatVector
import tensorflow as tf

# --- Load Data dari kolom 'utt' ---
df = pd.read_csv("teksAsli.csv").dropna().astype(str)
texts = df['utt'].tolist()

# --- Split Data ---
train_texts, test_texts = train_test_split(texts, test_size=0.2, random_state=42)

# --- Tokenisasi ---
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_texts)
vocab_size = len(tokenizer.word_index) + 1

# --- Hitung panjang maksimum ---
max_len = max([len(text_to_word_sequence(t)) for t in texts])

def encode(texts):
    seqs = tokenizer.texts_to_sequences(texts)
    return pad_sequences(seqs, maxlen=max_len, padding='post')

train_seq = encode(train_texts)
test_seq = encode(test_texts)

# --- Target = input untuk autoencoder ---
train_target = train_seq  # Tetap integer, tidak to_categorical

# --- Bangun Model LSTM ---
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=128))
model.add(LSTM(128))
model.add(RepeatVector(max_len))
model.add(LSTM(128, return_sequences=True))
model.add(TimeDistributed(Dense(vocab_size, activation='softmax')))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# --- Training ---
model.fit(train_seq, np.expand_dims(train_target, -1), epochs=50, batch_size=32, verbose=1)

# --- Fungsi Decode ---
reverse_word_map = dict(map(reversed, tokenizer.word_index.items()))
def sequence_to_text(sequence):
    return ' '.join([reverse_word_map.get(i, '') for i in sequence if i != 0])

# --- Parafrase Data Testing ---
preds = model.predict(test_seq)
pred_seqs = np.argmax(preds, axis=-1)
originals = test_texts
paraphrases = [sequence_to_text(seq) for seq in pred_seqs]

# --- Hitung BLEU ---
smoothie = SmoothingFunction().method4
scores = []

for ori, para in zip(originals, paraphrases):
    score = sentence_bleu(
        [text_to_word_sequence(ori)],
        text_to_word_sequence(para),
        smoothing_function=smoothie
    )
    scores.append(score)

# --- Simpan ke CSV ---
output_df = pd.DataFrame({
    'original': originals,
    'paraphrase': paraphrases,
    'bleu_score': scores
})
output_df.to_csv('hasil_parafrase.csv', index=False)
print("📁 File disimpan sebagai 'hasil_parafrase.csv'")
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.1217 - loss: 3.7066
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.2635 - loss: 3.6580
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2596 - loss: 3.5425
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2661 - loss: 3.2443
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.2577 - loss: 2.9234
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.2871 - loss: 2.9746
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2867 - loss: 2.8314
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.2871 - loss: 2.7458
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.2991 - loss: 2.7302
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2801 - loss: 2.7010
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.2957 - loss: 2.6042
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.3077 - loss: 2.5915
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.2964 - loss: 2.5775
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.2859 - loss: 2.5001
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.2846 - loss: 2.4957
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.2814 - loss: 2.4390
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.2970 - loss: 2.3570
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.2859 - loss: 2.3425
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2814 - loss: 2.3003
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.2872 - loss: 2.2489
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.2911 - loss: 2.1716
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3035 - loss: 2.1191
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.3288 - loss: 2.0509
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3639 - loss: 1.9809
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.3924 - loss: 1.8848
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4180 - loss: 1.7890
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4526 - loss: 1.7317
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5121 - loss: 1.6502
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5568 - loss: 1.5439
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5714 - loss: 1.5005
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5987 - loss: 1.4225
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6753 - loss: 1.3142
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6878 - loss: 1.2607
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6701 - loss: 1.1798
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6814 - loss: 1.1362
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7609 - loss: 1.0626
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7995 - loss: 0.9830
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7773 - loss: 0.9614
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7652 - loss: 0.8728
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8530 - loss: 0.8214
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8600 - loss: 0.7655
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8922 - loss: 0.7212
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9354 - loss: 0.6721
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9470 - loss: 0.6336
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9702 - loss: 0.5843
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9514 - loss: 0.5692
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9435 - loss: 0.5287
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9885 - loss: 0.4774
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9884 - loss: 0.4403
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9911 - loss: 0.4171
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000227D062DCF0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 655ms/step
# 📁 File disimpan sebagai 'hasil_parafrase.csv'
